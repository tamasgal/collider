# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../round1_magnetfactor2.csv", delim_whitespace=True, comment='#')

# %%
df.points.hist(bins=max(df.points))

# %%
plt.hist2d(df.x, df.y, weights=df['points'], bins=50);
